# %%
from evaluation import evaluation_calc

dataset_name = "beir"

evaluation_calc(
    dataset_name,
    top_k=500,
    similarity_threshold=0.3,  
    method="hybrid",
)
# Out:
# ⏱️ زمن التنفيذ: 902.00 ثانية
# {'AP': 0.20385383388017, 'nDCG@10': 0.25407105727738116, 'RR': 0.3874407309577122, 'R@10': 0.18043402181708476, 'P@10': 0.2278565539983614}

# %%
from evaluation import evaluation_calc

dataset_name = "antique"


evaluation_calc(
    dataset_name,
    top_k=10,
    similarity_threshold=0.3,  
    method="hybrid",
)
# Out:
# ⏱️ زمن التنفيذ: 1030.00 ثانية
# {'P@10': 0.2115746084089026, 'AP': 0.2445575987075332, 'RR': 0.40216370126259016, 'R@10': 0.2153260069982538, 'nDCG@10': 0.3136526006921}
