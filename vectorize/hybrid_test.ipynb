# %%
from hybrid import generate_hybrid

generate_hybrid('antique')
# Out:
# tfidf_matrix.shape: (403666, 255863)
# embeddings.shape: (403666, 768)
# ✅ hybrid_vectors created: (403666, 256631)

# %%
from hybrid import generate_hybrid

generate_hybrid('beir')
# Out:
# tfidf_matrix.shape: (382545, 713582)
# embeddings.shape: (382545, 768)
# ✅ hybrid_vectors created: (382545, 714350)

# %%
from tfidf import build_save_vectorizer

res= build_save_vectorizer('antique')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from tfidf import build_save_vectorizer
# ----> 3 res= build_save_vectorizer('antique')
#
# File c:\Users\Barakat\Lectures\IR\vectorize\tfidf.py:52, in build_save_vectorizer(dataset_name)
#      42     doc_ids.append(doc_id)
#      44 vectorizer = TfidfVectorizer(
#      45         tokenizer=tokenizer_with_dataset,
#      46         lowercase=False,
#    (...)     49         norm='l2'
#      50     )
# ---> 52 tfidf_matrix = vectorizer.fit_transform(raw_texts)
#      55 print(f"[✓] تم بناء وحفظ نموذج embeddings لمجموعة البيانات: {dataset_name}")
#      57 save_vectorizer(dataset_name=dataset_name,model=vectorizer)
#
# File c:\Users\Barakat\Lectures\IR\torchenv\Lib\site-packages\sklearn\feature_extraction\text.py:2104, in TfidfVectorizer.fit_transform(self, raw_documents, y)
# ...
